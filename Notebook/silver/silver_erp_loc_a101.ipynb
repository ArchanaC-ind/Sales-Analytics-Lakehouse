# %% [markdown]
# Initialization

# %%
import pyspark.sql.functions as F
from pyspark.sql.types import StringType, DateType
from pyspark.sql.functions import trim, col

# %% [markdown]
# Read Bronze table

# %%
df=spark.table("lakehouse_project.bronze.erp_loc_a101")

# %% [markdown]
# **Data Transformations**

# %% [markdown]
# Trimming

# %%
for field in df.schema.fields:
    if isinstance(field.dataType, StringType):
        df = df.withColumn(field.name, trim(col(field.name)))

# %% [markdown]
# Customer ID cleanup

# %%
df = df.withColumn("cid", F.regexp_replace(col("cid"), "-", ""))

# %% [markdown]
# Normalization

# %%
df = df.withColumn(
    "cntry",
    F.when(col("cntry") == "DE", "Germany")
     .when(col("cntry").isin("US", "USA"), "United States")
     .when((col("cntry") == "") | col("cntry").isNull(), "n/a")
     .otherwise(col("cntry"))
)

# %% [markdown]
# Rename columns

# %%
RENAME_MAP = {
    "cid": "customer_number",
    "cntry": "country"
}
for old_name, new_name in RENAME_MAP.items():
    df = df.withColumnRenamed(old_name, new_name)

# %% [markdown]
# Sanity check of dataframe

# %%
display(df.limit(10))

# %% [markdown]
# Writing silver table

# %%
df.write.mode("overwrite").format("delta").saveAsTable("lakehouse_project.silver.erp_customer_location")

# %% [markdown]
# Sanity check of silver table

# %%
# %sql
SELECT * FROM lakehouse_project.silver.erp_customer_location LIMIT 10
